# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import os
import csv
import time

# %%
fle = os.path.join("D:\\Dropbox\\SonicationBehavior\\SonBehData\\2016_10_19__11_23_51_424_220_450_test.txt")

exx = np.transpose(pd.read_csv(fle, sep = " ", header = None))

# %%
# convert data to m/s/s
data = np.array(exx.loc[:,1])*1000 / 10.17
data = data - np.mean(data)

log_rate = 200000.0

n =len(data) # length of the signal
k = np.arange(n, step = 1)
T = n/log_rate
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range

Y = np.fft.fft(data)/n * 2# fft computing and normalization
Y = Y[range(int(n/2))]

# calculate top frequency
ind = np.argpartition(abs(Y), -4)[-4:]
# Find highest point on the spectrum
peakFrq = frq[ind[::-1]]
pwr = (abs(Y)[ind[::-1]])
domPK = [x for (y,x) in sorted(zip(pwr,peakFrq), reverse = True)][0]

beeFrqPwr = pwr[peakFrq == domPK]

# %%
f, ax1 = plt.subplots()
f.set_figwidth(4.5)
f.set_figheight(1.5)
ax1.plot(np.array(range(len(exx)))/ float(log_rate), data,color = 'black', linewidth=0.5 )
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')
ax1.spines['left'].set_color('none')
ax1.spines['bottom'].set_color('none')
plt.yticks([])
ax1.set_ylabel("Acceleration\n(m/s/s)")
ax1.set_xlabel("Time (s)")
plt.tight_layout()
plt.savefig(r"D:\Dropbox\CallinStuff\MSDSE_2018_ParkCity\SonicationExample.png", dpi = 500)
#ax1.scatter(xs[peakind], data[peakind])

# %%
f, ax1 = plt.subplots()
f.set_figwidth(7.4)
f.set_figheight(1.5)
ax1.plot(np.array(range(len(exx)))/ float(log_rate), data,color = 'black', linewidth=0.5 )
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')
ax1.spines['left'].set_color('none')
ax1.spines['bottom'].set_color('none')
plt.yticks([])
ax1.set_ylabel("Acceleration\n(m/s/s)")
ax1.set_xlabel("Time (s)")
plt.tight_layout()
plt.savefig(r"D:\Dropbox\CallinStuff\MSDSE_2018_ParkCity\SonicationExample1.png", dpi = 500)
#ax1.scatter(xs[peakind], data[peakind])

# %% [markdown]
# # show buzz and not buzz

# %%
fle = os.path.join(r"D:\Dropbox\SonicationBehavior\SonBehData\SonicationBehaviorTrials_NoImages\BeeBlue6_28Nov2016_Hive4_high\2016_11_28__13_49_32\2016_11_28__13_51_00_911_395_450_test.txt")

exx = np.transpose(pd.read_csv(fle, sep = " ", header = None))
# convert data to m/s/s
data = np.array(exx.loc[:,1])*1000 / 10.17
data = data - np.mean(data)


f, ax1 = plt.subplots()
f.set_figwidth(7.4)
f.set_figheight(1.5)
ax1.plot(np.array(range(len(exx)))/ float(log_rate), data,color = 'black', linewidth=0.5 )
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')
ax1.spines['left'].set_color('none')
ax1.spines['bottom'].set_color('none')
plt.yticks([])
ax1.set_ylabel("Acceleration\n(m/s/s)")
ax1.set_xlabel("Time (s)")
plt.tight_layout()
plt.savefig(r"D:\Dropbox\CallinStuff\MSDSE_2018_ParkCity\NotBuzz.png", dpi = 500)
#ax1.scatter(xs[peakind], data[peakind])

# %%
ff = r"D:\Dropbox\SonicationBehavior\SonBehData\SonicationBehaviorTrials_NoImages\BeeBlue6_28Nov2016_Hive4_high\2016_11_28__13_49_32"

fle = os.path.join(ff, "2016_11_28__13_53_56_107_395_450_test" + ".txt")

exx = np.transpose(pd.read_csv(fle, sep = " ", header = None))
# convert data to m/s/s
data = np.array(exx.loc[:,1])*1000 / 10.17
data = data - np.mean(data)


f, ax1 = plt.subplots()
f.set_figwidth(7.4)
f.set_figheight(1.5)
ax1.plot(np.array(range(len(exx)))/ float(log_rate), data,color = 'black', linewidth=0.5 )
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')
ax1.spines['left'].set_color('none')
ax1.spines['bottom'].set_color('none')
plt.yticks([])
ax1.set_ylabel("Acceleration\n(m/s/s)")
ax1.set_xlabel("Time (s)")
plt.tight_layout()
plt.savefig(r"D:\Dropbox\CallinStuff\MSDSE_2018_ParkCity\BuzzStart.png", dpi = 500)
#ax1.scatter(xs[peakind], data[peakind])

# %%
ff = r"D:\Dropbox\SonicationBehavior\SonBehData\SonicationBehaviorTrials_NoImages\BeeBlue6_28Nov2016_Hive4_high\2016_11_28__13_49_32"

fle = os.path.join(ff, "2016_11_28__13_53_57_737_395_450_test" + ".txt")

exx = np.transpose(pd.read_csv(fle, sep = " ", header = None))
# convert data to m/s/s
data = np.array(exx.loc[:,1])*1000 / 10.17
data = data - np.mean(data)


f, ax1 = plt.subplots()
f.set_figwidth(7.4)
f.set_figheight(1.5)
ax1.plot(np.array(range(len(exx)))/ float(log_rate), data,color = 'black', linewidth=0.5 )
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')
ax1.spines['left'].set_color('none')
ax1.spines['bottom'].set_color('none')
plt.yticks([])
ax1.set_ylabel("Acceleration\n(m/s/s)")
ax1.set_xlabel("Time (s)")
plt.tight_layout()
plt.savefig(r"D:\Dropbox\CallinStuff\MSDSE_2018_ParkCity\FullBuzz.png", dpi = 500)
#ax1.scatter(xs[peakind], data[peakind])
