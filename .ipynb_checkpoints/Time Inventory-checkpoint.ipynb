# %%
## analyze time usage google sheet

# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('https://docs.google.com/spreadsheets/d/' + 
                   '1OPPbkBkkBJf5_TRd_TWioTfNZtfDlUlQiDoCfRpzdoI' +
                   '/export?gid=0&format=csv'
                  )
test.head(5)  # Same result as @TomAugspurger
# Out:
#           day   hour     category productive                           notes
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1         NaN  07:15      commute          n                             NaN
# 2         NaN  07:30     exercise          n                             NaN
# 3         NaN  08:15  maintenance          n  Trying to get title for my car
# 4         NaN  09:26     eScience          y             prep lightning talk

# %%
# %qtconsole

# %%
def cellFillBelow(dataframe, column):
    #loop through cells
    tmp = dataframe[column].copy()
    
    currInfo = tmp[0]
    for ii in range(len(tmp)):
        if pd.isnull(tmp[ii]):
            tmp[ii] = currInfo
        else:
            currInfo = tmp[ii]
    
    return(tmp)

# %%
test['day'] = cellFillBelow(test, 'day')

# %%
test.head()
# Out:
#           day   hour     category productive                           notes
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1  2 Oct 2017  07:15      commute          n                             NaN
# 2  2 Oct 2017  07:30     exercise          n                             NaN
# 3  2 Oct 2017  08:15  maintenance          n  Trying to get title for my car
# 4  2 Oct 2017  09:26     eScience          y             prep lightning talk

# %%
test.tail()
# Out:
#              day   hour       category productive  \
# 238  31 Oct 2017  09:00        meeting          n
# 239  31 Oct 2017  09:30        reading          y
# 240  31 Oct 2017  11:45        seminar          n
# 241  31 Oct 2017  12:15        reading          y
# 242  31 Oct 2017  15:30  pythonProgram          n
#
#                                                 notes
# 238                             met with Tom and Jake
# 239                         machine learning textbook
# 240  lunch career seminar with Tom Daniel at eScience
# 241                         machine learning textbook
# 242                                     time analysis

# %%
from datetime import datetime

# %%
times2 = [datetime.strptime(ii, "%H:%M") for ii in test['hour']]



datetime.strftime(times2[0],"%H:%M" )
# Out:
# '06:00'

# %%
timeDiffs = np.diff(times2)

# %%
def decimalHours(timedelta):
    duration =timedelta
    seconds = duration.total_seconds()
    hours = seconds / 3600
    return(hours)

timeDiffsHours = [decimalHours(jj) for jj in timeDiffs]
timeDiffsHours.append(0) # add a zero at the end of the dataset
test["timeSpent"] = timeDiffsHours
test.head()
# Out:
#           day   hour     category productive                           notes  \
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1  2 Oct 2017  07:15      commute          n                             NaN
# 2  2 Oct 2017  07:30     exercise          n                             NaN
# 3  2 Oct 2017  08:15  maintenance          n  Trying to get title for my car
# 4  2 Oct 2017  09:26     eScience          y             prep lightning talk
#
#    timeSpent
# 0   1.250000
# 1   0.250000
# 2   0.750000
# 3   1.183333
# 4   0.183333

# %%
# remove last entry for each day
def removeLastOfDay(dataframe, daycolumn):
    #loop through cells
    tmp = dataframe[daycolumn].copy()
    
    dropRows = []
    for ii in range(len(tmp)):
        try:
            if tmp[ii] != tmp[ii + 1]:
                dropRows.append(ii)
        except:
             dropRows.append(ii)
    
    return(dropRows)

# %%
rowRemove = removeLastOfDay(test, "day")

# %%
timeCalcs = test.drop(rowRemove)

# %%
timeCalcs
# Out:
#              day   hour             category productive  \
# 7                               response to reviewers   0.766667
# 8                                                 NaN   0.200000
# 9                                                 NaN   0.200000
# 10                               getting MA car title   0.500000
# 11                                                NaN   0.216667
# 12                                                NaN   1.250000
# 13            prepping for eScience teaching tomorrow   0.600000
# 14                                                NaN   1.066667
# 15                                      Welcome event   2.250000
# 17                                                NaN   1.250000
# 18                                                NaN   0.250000
# 19                                                NaN   0.750000
# 20                                                NaN   0.566667
# 21                          prep for meeting with Tom   0.183333
# 22                                           with tom   1.000000
# 23                                                NaN   0.266667
# 24                                                NaN   0.050000
# 25                          prep for meeting with Tom   0.066667
# 26                                                NaN   1.366667
# 27                                     Lunch seminar    1.500000
# 28                                                NaN   0.250000
# 29                                                NaN   3.250000
# 30                                            seminar   0.750000
# ..                                                ...        ...
# 209                getting vinyl from Seattle fabrics   1.250000
# 210                                               NaN   1.250000
# 211                          lunch with Andrew Gelman   1.250000
# 212                                               NaN   2.000000
# 213                                               NaN   1.166667
# 215                                               NaN   1.250000
# 216                                               NaN   0.250000
# 217                                               NaN   0.833333
# 218                                               NaN   0.666667
# 219                 submitting orders on purchasepath   0.666667
# 220                                               NaN   2.083333
# 221                                             NIFTI   1.250000
# 222                      Jeremy (Riffell lab meeting)   1.166667
# 223                                               NaN   1.333333
# 224                       played games and ate snacks   1.500000
# 226                                               NaN   1.416667
# 227                                               NaN   0.250000
# 228                                               NaN   0.500000
# 229                                               NaN   1.000000
# 230                                               NaN   2.500000
# 231                                               NaN   0.500000
# 232                                               NaN   6.000000
# 234                                               NaN   0.916667
# 235                                               NaN   0.250000
# 236                                               NaN   0.750000
# 237                                               NaN   0.750000
# 238                             met with Tom and Jake   0.500000
# 239                         machine learning textbook   2.250000
# 240  lunch career seminar with Tom Daniel at eScience   0.500000
# 241                         machine learning textbook   3.250000
#
# [222 rows x 6 columns]

# %%
g = timeCalcs.groupby('category')['timeSpent'].sum().reset_index(name='sum')

# %%
pd.DataFrame(g).sort_values("sum", ascending=False)
# Out:
#                category        sum
# 21         kalmia paper  28.216667
# 2          Kalmia paper  16.116667
# 36              seminar  15.666667
# 20         james' paper  13.300000
# 14             eScience  12.683333
# 40              wake up  12.666667
# 32  prep bee experiment  11.416667
# 18             exercise  10.800000
# 1          James' paper  10.183333
# 19            get ready   9.416667
# 25              meeting   7.866667
# 23                lunch   7.733333
# 10               coffee   7.466667
# 35              reading   7.000000
# 31                 prep   6.716667
# 24          maintenance   5.183333
# 22          lab meeting   5.100000
# 16                email   4.483333
# 11              commute   4.416667
# 7                   car   3.500000
# 6            brainstorm   2.833333
# 17               errand   2.750000
# 8           career fair   2.500000
# 3                  Prep   2.000000
# 26       mini-symposium   1.916667
# 28     neuroinformatics   1.833333
# 30             planning   1.833333
# 27           networking   1.500000
# 9              climbing   1.500000
# 15            eScience    1.250000
# 33            prep talk   1.166667
# 38               snooze   0.833333
# 13               comute   0.833333
# 29            ordering    0.750000
# 34           purchasing   0.666667
# 4             bee order   0.500000
# 12             commute    0.500000
# 5                  bike   0.500000
# 0           GANTT chart   0.333333
# 37                snack   0.200000
# 39           transition   0.066667

# %%
pd.Da
