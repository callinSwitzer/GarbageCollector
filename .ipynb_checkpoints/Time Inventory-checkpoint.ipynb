# %%
## analyze time usage google sheet

# %%
import sys
print(sys.version)
print(sys.executable)
# %matplotlib inline
# Out:
# 3.5.4 |Anaconda, Inc.| (default, Oct  5 2017, 02:58:14)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# /Users/cswitzer/anaconda/envs/p35/bin/python

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('https://docs.google.com/spreadsheets/d/' + 
                   '1OPPbkBkkBJf5_TRd_TWioTfNZtfDlUlQiDoCfRpzdoI' +
                   '/export?gid=0&format=csv'
                  )
test.head(5)  #
# Out:
#           day   hour     category productive                           notes
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1         NaN  07:15      commute          n                             NaN
# 2         NaN  07:30     exercise          n                             NaN
# 3         NaN  08:15  maintenance          n  Trying to get title for my car
# 4         NaN  09:26     eScience          y             prep lightning talk

# %%
# %qtconsole

# %%
def cellFillBelow(dataframe, column):
    #loop through cells
    tmp = dataframe[column].copy()
    
    currInfo = tmp[0]
    for ii in range(len(tmp)):
        if pd.isnull(tmp[ii]):
            tmp[ii] = currInfo
        else:
            currInfo = tmp[ii]
    
    return(tmp)

# %%
test['day'] = cellFillBelow(test, 'day')

# %%
test.head()
# Out:
#           day   hour     category productive                           notes
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1  2 Oct 2017  07:15      commute          n                             NaN
# 2  2 Oct 2017  07:30     exercise          n                             NaN
# 3  2 Oct 2017  08:15  maintenance          n  Trying to get title for my car
# 4  2 Oct 2017  09:26     eScience          y             prep lightning talk

# %%
test.tail()
# Out:
#              day   hour                        category productive notes
# 362  29 Nov 2017  08:00                          coffee        NaN   NaN
# 363  29 Nov 2017  08:30  kalmia paper - post acceptance        NaN   NaN
# 364  29 Nov 2017  12:00                           lunch        NaN   NaN
# 365  29 Nov 2017  12:30            prep for lab meeting        NaN   NaN
# 366  29 Nov 2017  17:00                             end        NaN   NaN

# %%
from datetime import datetime

# %%
times2 = [datetime.strptime(ii, "%H:%M") for ii in test['hour']]



datetime.strftime(times2[0],"%H:%M" )
# Out:
# '06:00'

# %%
timeDiffs = np.diff(times2)

# %%
def decimalHours(timedelta):
    duration =timedelta
    seconds = duration.total_seconds()
    hours = seconds / 3600
    return(hours)

timeDiffsHours = [decimalHours(jj) for jj in timeDiffs]
timeDiffsHours.append(0) # add a zero at the end of the dataset
test["timeSpent"] = timeDiffsHours
test.head()
# Out:
#           day   hour     category productive                           notes  \
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1  2 Oct 2017  07:15      commute          n                             NaN
# 2  2 Oct 2017  07:30     exercise          n                             NaN
# 3  2 Oct 2017  08:15  maintenance          n  Trying to get title for my car
# 4  2 Oct 2017  09:26     eScience          y             prep lightning talk
#
#    timeSpent
# 0   1.250000
# 1   0.250000
# 2   0.750000
# 3   1.183333
# 4   0.183333

# %%
# remove last entry for each day
def removeLastOfDay(dataframe, daycolumn):
    #loop through cells
    tmp = dataframe[daycolumn].copy()
    
    dropRows = []
    for ii in range(len(tmp)):
        try:
            if tmp[ii] != tmp[ii + 1]:
                dropRows.append(ii)
        except:
             dropRows.append(ii)
    
    return(dropRows)

# %%
rowRemove = removeLastOfDay(test, "day")

# %%
timeCalcs = test.drop(rowRemove)

# %%
timeCalcs
# Out:
#              day   hour                        category productive  \
# 0     2 Oct 2017  06:00                       get ready          n
# 1     2 Oct 2017  07:15                         commute          n
# 2     2 Oct 2017  07:30                        exercise          n
# 3     2 Oct 2017  08:15                     maintenance          n
# 4     2 Oct 2017  09:26                        eScience          y
# 5     2 Oct 2017  09:37                     maintenance          n
# 6     2 Oct 2017  09:53                      transition          n
# 7     2 Oct 2017  09:57                    kalmia paper          y
# 8     2 Oct 2017  10:43                           snack          n
# 9     2 Oct 2017  10:55                    kalmia paper          y
# 10    2 Oct 2017  11:07                     maintenance          n
# 11    2 Oct 2017  11:37                           lunch          n
# 12    2 Oct 2017  11:50                         seminar          y
# 13    2 Oct 2017  13:05                           email          n
# 14    2 Oct 2017  13:41                    kalmia paper          y
# 15    2 Oct 2017  14:45                        eScience          n
# 17    3 Oct 2017  06:00                       get ready          n
# 18    3 Oct 2017  07:15                         commute          n
# 19    3 Oct 2017  07:30                        exercise          n
# 20    3 Oct 2017  08:15                          coffee          n
# 21    3 Oct 2017  08:49                            prep          y
# 22    3 Oct 2017  09:00                         meeting          y
# 23    3 Oct 2017  10:00                           email          n
# 24    3 Oct 2017  10:16                    kalmia paper          y
# 25    3 Oct 2017  10:19                            prep          y
# 26    3 Oct 2017  10:23                    kalmia paper          y
# 27    3 Oct 2017  11:45                        eScience          n
# 28    3 Oct 2017  13:15                          coffee          n
# 29    3 Oct 2017  13:30                    kalmia paper          y
# 30    3 Oct 2017  16:45                        eScience          n
# ..           ...    ...                             ...        ...
# 330  17 Nov 2017  15:00                     lab meeting        NaN
# 332  20 Nov 2017  11:00                        bee care        NaN
# 333  20 Nov 2017  11:45                         seminar        NaN
# 334  20 Nov 2017  13:00                           lunch        NaN
# 335  20 Nov 2017  13:40  kalmia paper - post acceptance        NaN
# 337  21 Nov 2017  10:00                        bee care        NaN
# 338  21 Nov 2017  11:00  kalmia paper - post acceptance        NaN
# 340  22 Nov 2017  08:45                          coffee        NaN
# 341  22 Nov 2017  09:30  kalmia paper - post acceptance        NaN
# 342  22 Nov 2017  12:00                lunch and coffee        NaN
# 343  22 Nov 2017  14:00  kalmia paper - post acceptance        NaN
# 344  22 Nov 2017  15:30                        bee care        NaN
# 346  27 Nov 2017  08:00                       paperwork        NaN
# 347  27 Nov 2017  08:30                         commute        NaN
# 348  27 Nov 2017  09:00                           email        NaN
# 349  27 Nov 2017  09:30  kalmia paper - post acceptance        NaN
# 350  27 Nov 2017  11:45                         seminar        NaN
# 351  27 Nov 2017  13:00                           lunch        NaN
# 352  27 Nov 2017  13:30  kalmia paper - post acceptance        NaN
# 353  27 Nov 2017  17:00                           break        NaN
# 354  27 Nov 2017  21:00  kalmia paper - post acceptance        NaN
# 356  28 Noc 2017  08:00  kalmia paper - post acceptance        NaN
# 357  28 Noc 2017  11:45                         seminar        NaN
# 358  28 Noc 2017  13:30  kalmia paper - post acceptance        NaN
# 359  28 Noc 2017  16:30                         seminar        NaN
# 361  29 Nov 2017  07:15                        exercise        NaN
# 362  29 Nov 2017  08:00                          coffee        NaN
# 363  29 Nov 2017  08:30  kalmia paper - post acceptance        NaN
# 364  29 Nov 2017  12:00                           lunch        NaN
# 365  29 Nov 2017  12:30            prep for lab meeting        NaN
#
#                                             notes  timeSpent
# 0                                             NaN   1.250000
# 1                                             NaN   0.250000
# 2                                             NaN   0.750000
# 3                  Trying to get title for my car   1.183333
# 4                             prep lightning talk   0.183333
# 5    trying to get health insurance cards from UW   0.266667
# 6                                             NaN   0.066667
# 7                           response to reviewers   0.766667
# 8                                             NaN   0.200000
# 9                                             NaN   0.200000
# 10                           getting MA car title   0.500000
# 11                                            NaN   0.216667
# 12                                            NaN   1.250000
# 13        prepping for eScience teaching tomorrow   0.600000
# 14                                            NaN   1.066667
# 15                                  Welcome event   2.250000
# 17                                            NaN   1.250000
# 18                                            NaN   0.250000
# 19                                            NaN   0.750000
# 20                                            NaN   0.566667
# 21                      prep for meeting with Tom   0.183333
# 22                                       with tom   1.000000
# 23                                            NaN   0.266667
# 24                                            NaN   0.050000
# 25                      prep for meeting with Tom   0.066667
# 26                                            NaN   1.366667
# 27                                 Lunch seminar    1.500000
# 28                                            NaN   0.250000
# 29                                            NaN   3.250000
# 30                                        seminar   0.750000
# ..                                            ...        ...
# 330                                           NaN   2.000000
# 332                     I was sick in the morning   0.750000
# 333                                           NaN   1.250000
# 334                                           NaN   0.666667
# 335   getting forms signed and making final edits   3.333333
# 337                                           NaN   1.000000
# 338                                           NaN   4.500000
# 340                                           NaN   0.750000
# 341                           writing lay summary   2.500000
# 342                                           NaN   2.000000
# 343         prepping code and data for submission   1.500000
# 344                                           NaN   1.500000
# 346                                           NaN   0.500000
# 347                                           NaN   0.500000
# 348                                           NaN   0.500000
# 349                                           NaN   2.250000
# 350                                           NaN   1.250000
# 351                                           NaN   0.500000
# 352                                           NaN   3.500000
# 353                                           NaN   4.000000
# 354                                           NaN   1.000000
# 356                                           NaN   3.750000
# 357                                           NaN   1.750000
# 358                                           NaN   3.000000
# 359                                           NaN   1.000000
# 361                                           NaN   0.750000
# 362                                           NaN   0.500000
# 363                                           NaN   3.500000
# 364                                           NaN   0.500000
# 365                                           NaN   4.500000
#
# [328 rows x 6 columns]

# %%
timeCalcs
# Out:
#              day   hour                        category productive  \
# 0     2 Oct 2017  06:00                       get ready          n
# 1     2 Oct 2017  07:15                         commute          n
# 2     2 Oct 2017  07:30                        exercise          n
# 3     2 Oct 2017  08:15                     maintenance          n
# 4     2 Oct 2017  09:26                        eScience          y
# 5     2 Oct 2017  09:37                     maintenance          n
# 6     2 Oct 2017  09:53                      transition          n
# 7     2 Oct 2017  09:57                    kalmia paper          y
# 8     2 Oct 2017  10:43                           snack          n
# 9     2 Oct 2017  10:55                    kalmia paper          y
# 10    2 Oct 2017  11:07                     maintenance          n
# 11    2 Oct 2017  11:37                           lunch          n
# 12    2 Oct 2017  11:50                         seminar          y
# 13    2 Oct 2017  13:05                           email          n
# 14    2 Oct 2017  13:41                    kalmia paper          y
# 15    2 Oct 2017  14:45                        eScience          n
# 17    3 Oct 2017  06:00                       get ready          n
# 18    3 Oct 2017  07:15                         commute          n
# 19    3 Oct 2017  07:30                        exercise          n
# 20    3 Oct 2017  08:15                          coffee          n
# 21    3 Oct 2017  08:49                            prep          y
# 22    3 Oct 2017  09:00                         meeting          y
# 23    3 Oct 2017  10:00                           email          n
# 24    3 Oct 2017  10:16                    kalmia paper          y
# 25    3 Oct 2017  10:19                            prep          y
# 26    3 Oct 2017  10:23                    kalmia paper          y
# 27    3 Oct 2017  11:45                        eScience          n
# 28    3 Oct 2017  13:15                          coffee          n
# 29    3 Oct 2017  13:30                    kalmia paper          y
# 30    3 Oct 2017  16:45                        eScience          n
# ..           ...    ...                             ...        ...
# 330  17 Nov 2017  15:00                     lab meeting        NaN
# 332  20 Nov 2017  11:00                        bee care        NaN
# 333  20 Nov 2017  11:45                         seminar        NaN
# 334  20 Nov 2017  13:00                           lunch        NaN
# 335  20 Nov 2017  13:40  kalmia paper - post acceptance        NaN
# 337  21 Nov 2017  10:00                        bee care        NaN
# 338  21 Nov 2017  11:00  kalmia paper - post acceptance        NaN
# 340  22 Nov 2017  08:45                          coffee        NaN
# 341  22 Nov 2017  09:30  kalmia paper - post acceptance        NaN
# 342  22 Nov 2017  12:00                lunch and coffee        NaN
# 343  22 Nov 2017  14:00  kalmia paper - post acceptance        NaN
# 344  22 Nov 2017  15:30                        bee care        NaN
# 346  27 Nov 2017  08:00                       paperwork        NaN
# 347  27 Nov 2017  08:30                         commute        NaN
# 348  27 Nov 2017  09:00                           email        NaN
# 349  27 Nov 2017  09:30  kalmia paper - post acceptance        NaN
# 350  27 Nov 2017  11:45                         seminar        NaN
# 351  27 Nov 2017  13:00                           lunch        NaN
# 352  27 Nov 2017  13:30  kalmia paper - post acceptance        NaN
# 353  27 Nov 2017  17:00                           break        NaN
# 354  27 Nov 2017  21:00  kalmia paper - post acceptance        NaN
# 356  28 Noc 2017  08:00  kalmia paper - post acceptance        NaN
# 357  28 Noc 2017  11:45                         seminar        NaN
# 358  28 Noc 2017  13:30  kalmia paper - post acceptance        NaN
# 359  28 Noc 2017  16:30                         seminar        NaN
# 361  29 Nov 2017  07:15                        exercise        NaN
# 362  29 Nov 2017  08:00                          coffee        NaN
# 363  29 Nov 2017  08:30  kalmia paper - post acceptance        NaN
# 364  29 Nov 2017  12:00                           lunch        NaN
# 365  29 Nov 2017  12:30            prep for lab meeting        NaN
#
#                                             notes  timeSpent
# 0                                             NaN   1.250000
# 1                                             NaN   0.250000
# 2                                             NaN   0.750000
# 3                  Trying to get title for my car   1.183333
# 4                             prep lightning talk   0.183333
# 5    trying to get health insurance cards from UW   0.266667
# 6                                             NaN   0.066667
# 7                           response to reviewers   0.766667
# 8                                             NaN   0.200000
# 9                                             NaN   0.200000
# 10                           getting MA car title   0.500000
# 11                                            NaN   0.216667
# 12                                            NaN   1.250000
# 13        prepping for eScience teaching tomorrow   0.600000
# 14                                            NaN   1.066667
# 15                                  Welcome event   2.250000
# 17                                            NaN   1.250000
# 18                                            NaN   0.250000
# 19                                            NaN   0.750000
# 20                                            NaN   0.566667
# 21                      prep for meeting with Tom   0.183333
# 22                                       with tom   1.000000
# 23                                            NaN   0.266667
# 24                                            NaN   0.050000
# 25                      prep for meeting with Tom   0.066667
# 26                                            NaN   1.366667
# 27                                 Lunch seminar    1.500000
# 28                                            NaN   0.250000
# 29                                            NaN   3.250000
# 30                                        seminar   0.750000
# ..                                            ...        ...
# 330                                           NaN   2.000000
# 332                     I was sick in the morning   0.750000
# 333                                           NaN   1.250000
# 334                                           NaN   0.666667
# 335   getting forms signed and making final edits   3.333333
# 337                                           NaN   1.000000
# 338                                           NaN   4.500000
# 340                                           NaN   0.750000
# 341                           writing lay summary   2.500000
# 342                                           NaN   2.000000
# 343         prepping code and data for submission   1.500000
# 344                                           NaN   1.500000
# 346                                           NaN   0.500000
# 347                                           NaN   0.500000
# 348                                           NaN   0.500000
# 349                                           NaN   2.250000
# 350                                           NaN   1.250000
# 351                                           NaN   0.500000
# 352                                           NaN   3.500000
# 353                                           NaN   4.000000
# 354                                           NaN   1.000000
# 356                                           NaN   3.750000
# 357                                           NaN   1.750000
# 358                                           NaN   3.000000
# 359                                           NaN   1.000000
# 361                                           NaN   0.750000
# 362                                           NaN   0.500000
# 363                                           NaN   3.500000
# 364                                           NaN   0.500000
# 365                                           NaN   4.500000
#
# [328 rows x 6 columns]

# %%
g = timeCalcs.groupby('category')['timeSpent'].sum().reset_index(name='sum')

# %%
g2 = pd.DataFrame(g).sort_values("sum", ascending=False)
g2.index = range(len(g2))
g2.head()
# Out:
#                          category        sum
# 0                    kalmia paper  36.216667
# 1  kalmia paper - post acceptance  28.833333
# 2                         seminar  26.083333
# 3              Moore/Sloan Summit  23.000000
# 4                   pythonProgram  22.300000

# %%
plt.figure(figsize=(50, 20))
plt.tick_params(axis='both', which='major', labelsize=50)
plt.xlabel('Activity', fontsize = 60)
plt.ylabel('Hours', fontsize = 60)
sns.barplot(g2.category, np.array(g2["sum"]))
plt.xticks(rotation="vertical")
plt.show()

# %%
np.array(g["sum"])
# Out:
# array([  0.66666667,   0.33333333,  12.01666667,  16.11666667,
#         23.        ,   2.        ,   1.5       ,   3.91666667,
#          0.5       ,   0.5       ,   2.83333333,   4.        ,
#          3.5       ,   2.5       ,   2.5       ,  11.55      ,
#          0.25      ,   6.66666667,   0.5       ,  13.68333333,
#          1.25      ,   4.98333333,   2.75      ,  15.13333333,
#         12.58333333,   1.66666667,  13.3       ,  36.21666667,
#         28.83333333,   8.6       ,  12.41666667,   2.        ,
#          5.18333333,  12.61666667,   1.91666667,   1.5       ,
#         12.08333333,   2.83333333,   0.91666667,   7.        ,
#          4.16666667,   1.83333333,   6.71666667,  12.41666667,
#          4.5       ,   1.16666667,   0.66666667,  22.3       ,
#         12.65      ,  26.08333333,   1.5       ,   0.2       ,
#          0.83333333,   4.83333333,   0.06666667,  16.33333333])

# %%
len(np.unique(timeCalcs.day))
# Out:
# 39

# %%
g2["sum"].sum()
# Out:
# 408.5833333333334

# %%
g2
# Out:
#                                category        sum
# 0                          kalmia paper  36.216667
# 1        kalmia paper - post acceptance  28.833333
# 2                               seminar  26.083333
# 3                    Moore/Sloan Summit  23.000000
# 4                         pythonProgram  22.300000
# 5                               wake up  16.333333
# 6                          Kalmia paper  16.116667
# 7                              exercise  15.133333
# 8                              eScience  13.683333
# 9                          james' paper  13.300000
# 10                              reading  12.650000
# 11                              meeting  12.616667
# 12                            get ready  12.583333
# 13                  prep bee experiment  12.416667
# 14                                lunch  12.416667
# 15              neural network learning  12.083333
# 16                         James' paper  12.016667
# 17                               coffee  11.550000
# 18                          lab meeting   8.600000
# 19                          out of town   7.000000
# 20                                 prep   6.716667
# 21                              commute   6.666667
# 22                          maintenance   5.183333
# 23                                email   4.983333
# 24                sonication manuscript   4.833333
# 25                 prep for lab meeting   4.500000
# 26                            paperwork   4.166667
# 27                                break   4.000000
# 28                             bee care   3.916667
# 29                                  car   3.500000
# 30                     neuroinformatics   2.833333
# 31                           brainstorm   2.833333
# 32                               errand   2.750000
# 33                             climbing   2.500000
# 34                          career fair   2.500000
# 35                                 Prep   2.000000
# 36                     lunch and coffee   2.000000
# 37                       mini-symposium   1.916667
# 38                             planning   1.833333
# 39                               get up   1.666667
# 40  setting up multi-camera acquisition   1.500000
# 41                        bee cage setu   1.500000
# 42                           networking   1.500000
# 43                            eScience    1.250000
# 44                            prep talk   1.166667
# 45                            ordering    0.916667
# 46                               snooze   0.833333
# 47                           purchasing   0.666667
# 48                                lunch   0.666667
# 49                             commute    0.500000
# 50                                 bike   0.500000
# 51                            bee order   0.500000
# 52                          GANTT chart   0.333333
# 53                               commut   0.250000
# 54                                snack   0.200000
# 55                           transition   0.066667

# %%
nonWorkActivities = ["bike", "snooze", "exercise", "commute", "climbing", "comute", "wake up", "get ready"]

rowRemove = [g2.category[ii] not in nonWorkActivities for ii in range(len(g2))]

# %%
g3 = g2[rowRemove]

# %%
g3["sum"].sum()/len(np.unique(timeCalcs.day))
# Out:
# 9.07777777777778

# %%
len(timeCalcs)
# Out:
# 328

# %%
# calculate hours for each day
rowRemove = [timeCalcs.category[ii] not in nonWorkActivities for ii in timeCalcs.index]

timecalcs2 =  timeCalcs[rowRemove]

dailyHours= timecalcs2.groupby("day")['timeSpent'].sum().reset_index(name='sum')
dailyHours.sort_values("sum")
# Out:
#             day        sum
# 18  21 Nov 2017   5.500000
# 16  20 Nov 2017   6.000000
# 37   9 Nov 2017   7.000000
# 22  25 Oct 2017   8.166667
# 5   13 Oct 2017   8.250000
# 19  22 Nov 2017   8.250000
# 3   12 Oct 2017   8.250000
# 17  20 Oct 2017   8.350000
# 14   2 Nov 2017   8.416667
# 34   6 Oct 2017   8.500000
# 12  18 Oct 2017   8.666667
# 27   3 Nov 2017   8.750000
# 7   15 Nov 2017   8.750000
# 32   5 Oct 2017   8.750000
# 15   2 Oct 2017   8.750000
# 23  26 Oct 2017   8.916667
# 31   4 Oct 2017   8.933333
# 26  29 Nov 2017   9.000000
# 20  23 Oct 2017   9.000000
# 0    1 Nov 2017   9.000000
# 1   10 Oct 2017   9.083333
# 11  17 Oct 2017   9.166667
# 38   9 Oct 2017   9.166667
# 28   3 Oct 2017   9.250000
# 21  24 Oct 2017   9.450000
# 25  28 Noc 2017   9.500000
# 13  19 Oct 2017   9.500000
# 30  31 Oct 2017   9.500000
# 6   14 Nov 2017   9.716667
# 9   16 Oct 2017   9.833333
# 2   11 Oct 2017   9.833333
# 8   16 Nov 2017   9.916667
# 10  17 Nov 2017   9.916667
# 33   6 Nov 2017  10.000000
# 35   7 Nov 2017  10.000000
# 36   8 Nov 2017  10.000000
# 29  30 Oct 2017  10.000000
# 4   13 Nov 2017  11.500000
# 24  27 Nov 2017  13.500000

# %%
plt.figure(figsize=(50, 20))
plt.tick_params(axis='both', which='major', labelsize=50)
plt.xlabel('Activity', fontsize = 60)
plt.ylabel('Hours', fontsize = 60)
sns.barplot(g3.category, np.array(g3["sum"]))
plt.xticks(rotation="vertical")
plt.show()

# %%
g3
