# %%
## analyze time usage google sheet

# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('https://docs.google.com/spreadsheets/d/' + 
                   '1OPPbkBkkBJf5_TRd_TWioTfNZtfDlUlQiDoCfRpzdoI' +
                   '/export?gid=0&format=csv'
                  )
test.head(5)  #
# Out:
#           day   hour     category productive                           notes
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1         NaN  07:15      commute          n                             NaN
# 2         NaN  07:30     exercise          n                             NaN
# 3         NaN  08:15  maintenance          n  Trying to get title for my car
# 4         NaN  09:26     eScience          y             prep lightning talk

# %%
# %qtconsole

# %%
def cellFillBelow(dataframe, column):
    #loop through cells
    tmp = dataframe[column].copy()
    
    currInfo = tmp[0]
    for ii in range(len(tmp)):
        if pd.isnull(tmp[ii]):
            tmp[ii] = currInfo
        else:
            currInfo = tmp[ii]
    
    return(tmp)

# %%
test['day'] = cellFillBelow(test, 'day')

# %%
test.head()
# Out:
#           day   hour     category productive                           notes
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1  2 Oct 2017  07:15      commute          n                             NaN
# 2  2 Oct 2017  07:30     exercise          n                             NaN
# 3  2 Oct 2017  08:15  maintenance          n  Trying to get title for my car
# 4  2 Oct 2017  09:26     eScience          y             prep lightning talk

# %%
test.tail()
# Out:
#             day   hour   category productive                            notes
# 251  1 Nov 2017  12:00      lunch        NaN                              NaN
# 252  1 Nov 2017  12:30  paperwork        NaN  reimbursements for bee supplies
# 253  1 Nov 2017  13:00     coffee        NaN              postdoc coffee hour
# 254  1 Nov 2017  14:00  paperwork        NaN  reimbursements for bee supplies
# 255  1 Nov 2017  14:51    reading        NaN        machine learning textbook

# %%
from datetime import datetime

# %%
times2 = [datetime.strptime(ii, "%H:%M") for ii in test['hour']]



datetime.strftime(times2[0],"%H:%M" )
# Out:
# '06:00'

# %%
timeDiffs = np.diff(times2)

# %%
def decimalHours(timedelta):
    duration =timedelta
    seconds = duration.total_seconds()
    hours = seconds / 3600
    return(hours)

timeDiffsHours = [decimalHours(jj) for jj in timeDiffs]
timeDiffsHours.append(0) # add a zero at the end of the dataset
test["timeSpent"] = timeDiffsHours
test.head()
# Out:
#           day   hour     category productive                           notes  \
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1  2 Oct 2017  07:15      commute          n                             NaN
# 2  2 Oct 2017  07:30     exercise          n                             NaN
# 3  2 Oct 2017  08:15  maintenance          n  Trying to get title for my car
# 4  2 Oct 2017  09:26     eScience          y             prep lightning talk
#
#    timeSpent
# 0   1.250000
# 1   0.250000
# 2   0.750000
# 3   1.183333
# 4   0.183333

# %%
# remove last entry for each day
def removeLastOfDay(dataframe, daycolumn):
    #loop through cells
    tmp = dataframe[daycolumn].copy()
    
    dropRows = []
    for ii in range(len(tmp)):
        try:
            if tmp[ii] != tmp[ii + 1]:
                dropRows.append(ii)
        except:
             dropRows.append(ii)
    
    return(dropRows)

# %%
rowRemove = removeLastOfDay(test, "day")

# %%
timeCalcs = test.drop(rowRemove)

# %%
timeCalcs
# Out:
#              day   hour             category productive  \
# 0     2 Oct 2017  06:00            get ready          n
# 1     2 Oct 2017  07:15              commute          n
# 2     2 Oct 2017  07:30             exercise          n
# 3     2 Oct 2017  08:15          maintenance          n
# 4     2 Oct 2017  09:26             eScience          y
# 5     2 Oct 2017  09:37          maintenance          n
# 6     2 Oct 2017  09:53           transition          n
# 7     2 Oct 2017  09:57         kalmia paper          y
# 8     2 Oct 2017  10:43                snack          n
# 9     2 Oct 2017  10:55         kalmia paper          y
# 10    2 Oct 2017  11:07          maintenance          n
# 11    2 Oct 2017  11:37                lunch          n
# 12    2 Oct 2017  11:50              seminar          y
# 13    2 Oct 2017  13:05                email          n
# 14    2 Oct 2017  13:41         kalmia paper          y
# 15    2 Oct 2017  14:45             eScience          n
# 17    3 Oct 2017  06:00            get ready          n
# 18    3 Oct 2017  07:15              commute          n
# 19    3 Oct 2017  07:30             exercise          n
# 20    3 Oct 2017  08:15               coffee          n
# 21    3 Oct 2017  08:49                 prep          y
# 22    3 Oct 2017  09:00              meeting          y
# 23    3 Oct 2017  10:00                email          n
# 24    3 Oct 2017  10:16         kalmia paper          y
# 25    3 Oct 2017  10:19                 prep          y
# 26    3 Oct 2017  10:23         kalmia paper          y
# 27    3 Oct 2017  11:45             eScience          n
# 28    3 Oct 2017  13:15               coffee          n
# 29    3 Oct 2017  13:30         kalmia paper          y
# 30    3 Oct 2017  16:45             eScience          n
# ..           ...    ...                  ...        ...
# 222  26 Oct 2017  11:45              seminar          n
# 223  26 Oct 2017  13:00              seminar          n
# 224  26 Oct 2017  14:10  prep bee experiment          y
# 225  26 Oct 2017  15:30          lab meeting          n
# 227  30 Oct 2017  06:20              wake up          n
# 228  30 Oct 2017  07:45              commute          n
# 229  30 Oct 2017  08:00             exercise          n
# 230  30 Oct 2017  08:30  prep bee experiment          y
# 231  30 Oct 2017  09:30         kalmia paper          y
# 232  30 Oct 2017  12:00                lunch          n
# 233  30 Oct 2017  12:30         kalmia paper          y
# 235  31 Oct 2017  06:20              wake up          n
# 236  31 Oct 2017  07:15              commute          n
# 237  31 Oct 2017  07:30             exercise          n
# 238  31 Oct 2017  08:15  prep bee experiment          y
# 239  31 Oct 2017  09:00              meeting          n
# 240  31 Oct 2017  09:30              reading          y
# 241  31 Oct 2017  11:45              seminar          n
# 242  31 Oct 2017  12:15              reading          y
# 243  31 Oct 2017  15:30        pythonProgram          n
# 244  31 Oct 2017  16:20              seminar          n
# 245  31 Oct 2017  17:30        pythonProgram          n
# 247   1 Nov 2017  06:40              wake up          n
# 248   1 Nov 2017  08:00        pythonProgram          n
# 249   1 Nov 2017  10:00             eScience          n
# 250   1 Nov 2017  11:00        pythonProgram          n
# 251   1 Nov 2017  12:00                lunch        NaN
# 252   1 Nov 2017  12:30            paperwork        NaN
# 253   1 Nov 2017  13:00               coffee        NaN
# 254   1 Nov 2017  14:00            paperwork        NaN
#
#                                                 notes  timeSpent
# 0                                                 NaN   1.250000
# 1                                                 NaN   0.250000
# 2                                                 NaN   0.750000
# 3                      Trying to get title for my car   1.183333
# 4                                 prep lightning talk   0.183333
# 5        trying to get health insurance cards from UW   0.266667
# 6                                                 NaN   0.066667
# 7                               response to reviewers   0.766667
# 8                                                 NaN   0.200000
# 9                                                 NaN   0.200000
# 10                               getting MA car title   0.500000
# 11                                                NaN   0.216667
# 12                                                NaN   1.250000
# 13            prepping for eScience teaching tomorrow   0.600000
# 14                                                NaN   1.066667
# 15                                      Welcome event   2.250000
# 17                                                NaN   1.250000
# 18                                                NaN   0.250000
# 19                                                NaN   0.750000
# 20                                                NaN   0.566667
# 21                          prep for meeting with Tom   0.183333
# 22                                           with tom   1.000000
# 23                                                NaN   0.266667
# 24                                                NaN   0.050000
# 25                          prep for meeting with Tom   0.066667
# 26                                                NaN   1.366667
# 27                                     Lunch seminar    1.500000
# 28                                                NaN   0.250000
# 29                                                NaN   3.250000
# 30                                            seminar   0.750000
# ..                                                ...        ...
# 222                                             NIFTI   1.250000
# 223                      Jeremy (Riffell lab meeting)   1.166667
# 224                                               NaN   1.333333
# 225                       played games and ate snacks   1.500000
# 227                                               NaN   1.416667
# 228                                               NaN   0.250000
# 229                                               NaN   0.500000
# 230                                               NaN   1.000000
# 231                                               NaN   2.500000
# 232                                               NaN   0.500000
# 233                                               NaN   6.000000
# 235                                               NaN   0.916667
# 236                                               NaN   0.250000
# 237                                               NaN   0.750000
# 238                                               NaN   0.750000
# 239                             met with Tom and Jake   0.500000
# 240                         machine learning textbook   2.250000
# 241  lunch career seminar with Tom Daniel at eScience   0.500000
# 242                         machine learning textbook   3.250000
# 243                                     time analysis   0.833333
# 244                                 community seminar   1.166667
# 245                                               NaN   0.250000
# 247                                               NaN   1.333333
# 248                                               NaN   2.000000
# 249         writing bio and personal info for website   1.000000
# 250                                               NaN   1.000000
# 251                                               NaN   0.500000
# 252                   reimbursements for bee supplies   0.500000
# 253                               postdoc coffee hour   1.000000
# 254                   reimbursements for bee supplies   0.850000
#
# [234 rows x 6 columns]

# %%
# cluster categories
from jellyfish import jaro_distance

words = [ll.lower().rstrip() for ll in timeCalcs.category]
timeCalcs["category"] = words.copy()
def d(coord):
    i, j = coord 
    return (1 - jaro_distance(words[i], words[j]))

ingd = np.triu_indices(len(words), 1)
stff = np.apply_along_axis(d, 0, ingd)

import scipy.cluster.hierarchy

Z = scipy.cluster.hierarchy.linkage(stff)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(50, 20))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')

scipy.cluster.hierarchy.dendrogram(Z, leaf_rotation=90., leaf_font_size=8., labels = np.array(words)
                                  )
plt.savefig("C:\\Users\Combes4\\Desktop\\Hclust.pdf")
plt.show()

# combine clusters
timeCalcs["cluster"] = scipy.cluster.hierarchy.fcluster(Z, 0.5)


timeCalcs["clusterGroup"] = np.zeros(len(timeCalcs))
for ii in np.unique(timeCalcs.cluster):
    clustWords = timeCalcs.category[timeCalcs.cluster == ii]
    pic = np.unique(clustWords)
    clusterGp = ', '.join([''.join(x) for x in pic])
    timeCalcs.loc[timeCalcs.cluster == ii, "clusterGroup"] = clusterGp

# %%
timeCalcs
# Out:
#              day   hour             category productive  \
# 0     2 Oct 2017  06:00            get ready          n
# 1     2 Oct 2017  07:15              commute          n
# 2     2 Oct 2017  07:30             exercise          n
# 3     2 Oct 2017  08:15          maintenance          n
# 4     2 Oct 2017  09:26             escience          y
# 5     2 Oct 2017  09:37          maintenance          n
# 6     2 Oct 2017  09:53           transition          n
# 7     2 Oct 2017  09:57         kalmia paper          y
# 8     2 Oct 2017  10:43                snack          n
# 9     2 Oct 2017  10:55         kalmia paper          y
# 10    2 Oct 2017  11:07          maintenance          n
# 11    2 Oct 2017  11:37                lunch          n
# 12    2 Oct 2017  11:50              seminar          y
# 13    2 Oct 2017  13:05                email          n
# 14    2 Oct 2017  13:41         kalmia paper          y
# 15    2 Oct 2017  14:45             escience          n
# 17    3 Oct 2017  06:00            get ready          n
# 18    3 Oct 2017  07:15              commute          n
# 19    3 Oct 2017  07:30             exercise          n
# 20    3 Oct 2017  08:15               coffee          n
# 21    3 Oct 2017  08:49                 prep          y
# 22    3 Oct 2017  09:00              meeting          y
# 23    3 Oct 2017  10:00                email          n
# 24    3 Oct 2017  10:16         kalmia paper          y
# 25    3 Oct 2017  10:19                 prep          y
# 26    3 Oct 2017  10:23         kalmia paper          y
# 27    3 Oct 2017  11:45             escience          n
# 28    3 Oct 2017  13:15               coffee          n
# 29    3 Oct 2017  13:30         kalmia paper          y
# 30    3 Oct 2017  16:45             escience          n
# ..           ...    ...                  ...        ...
# 222  26 Oct 2017  11:45              seminar          n
# 223  26 Oct 2017  13:00              seminar          n
# 224  26 Oct 2017  14:10  prep bee experiment          y
# 225  26 Oct 2017  15:30          lab meeting          n
# 227  30 Oct 2017  06:20              wake up          n
# 228  30 Oct 2017  07:45              commute          n
# 229  30 Oct 2017  08:00             exercise          n
# 230  30 Oct 2017  08:30  prep bee experiment          y
# 231  30 Oct 2017  09:30         kalmia paper          y
# 232  30 Oct 2017  12:00                lunch          n
# 233  30 Oct 2017  12:30         kalmia paper          y
# 235  31 Oct 2017  06:20              wake up          n
# 236  31 Oct 2017  07:15              commute          n
# 237  31 Oct 2017  07:30             exercise          n
# 238  31 Oct 2017  08:15  prep bee experiment          y
# 239  31 Oct 2017  09:00              meeting          n
# 240  31 Oct 2017  09:30              reading          y
# 241  31 Oct 2017  11:45              seminar          n
# 242  31 Oct 2017  12:15              reading          y
# 243  31 Oct 2017  15:30        pythonprogram          n
# 244  31 Oct 2017  16:20              seminar          n
# 245  31 Oct 2017  17:30        pythonprogram          n
# 247   1 Nov 2017  06:40              wake up          n
# 248   1 Nov 2017  08:00        pythonprogram          n
# 249   1 Nov 2017  10:00             escience          n
# 250   1 Nov 2017  11:00        pythonprogram          n
# 251   1 Nov 2017  12:00                lunch        NaN
# 252   1 Nov 2017  12:30            paperwork        NaN
# 253   1 Nov 2017  13:00               coffee        NaN
# 254   1 Nov 2017  14:00            paperwork        NaN
#
#                                                 notes  timeSpent  cluster  \
# 0                                                 NaN   1.250000       23
# 1                                                 NaN   0.250000        8
# 2                                                 NaN   0.750000       10
# 3                      Trying to get title for my car   1.183333       19
# 4                                 prep lightning talk   0.183333       11
# 5        trying to get health insurance cards from UW   0.266667       19
# 6                                                 NaN   0.066667       20
# 7                               response to reviewers   0.766667        6
# 8                                                 NaN   0.200000       34
# 9                                                 NaN   0.200000        6
# 10                               getting MA car title   0.500000       19
# 11                                                NaN   0.216667        9
# 12                                                NaN   1.250000       21
# 13            prepping for eScience teaching tomorrow   0.600000       22
# 14                                                NaN   1.066667        6
# 15                                      Welcome event   2.250000       11
# 17                                                NaN   1.250000       23
# 18                                                NaN   0.250000        8
# 19                                                NaN   0.750000       10
# 20                                                NaN   0.566667        7
# 21                          prep for meeting with Tom   0.183333       15
# 22                                           with tom   1.000000       28
# 23                                                NaN   0.266667       22
# 24                                                NaN   0.050000        6
# 25                          prep for meeting with Tom   0.066667       15
# 26                                                NaN   1.366667        6
# 27                                     Lunch seminar    1.500000       11
# 28                                                NaN   0.250000        7
# 29                                                NaN   3.250000        6
# 30                                            seminar   0.750000       11
# ..                                                ...        ...      ...
# 222                                             NIFTI   1.250000       21
# 223                      Jeremy (Riffell lab meeting)   1.166667       21
# 224                                               NaN   1.333333       14
# 225                       played games and ate snacks   1.500000       29
# 227                                               NaN   1.416667        4
# 228                                               NaN   0.250000        8
# 229                                               NaN   0.500000       10
# 230                                               NaN   1.000000       14
# 231                                               NaN   2.500000        6
# 232                                               NaN   0.500000        9
# 233                                               NaN   6.000000        6
# 235                                               NaN   0.916667        4
# 236                                               NaN   0.250000        8
# 237                                               NaN   0.750000       10
# 238                                               NaN   0.750000       14
# 239                             met with Tom and Jake   0.500000       28
# 240                         machine learning textbook   2.250000       25
# 241  lunch career seminar with Tom Daniel at eScience   0.500000       21
# 242                         machine learning textbook   3.250000       25
# 243                                     time analysis   0.833333        2
# 244                                 community seminar   1.166667       21
# 245                                               NaN   0.250000        2
# 247                                               NaN   1.333333        4
# 248                                               NaN   2.000000        2
# 249         writing bio and personal info for website   1.000000       11
# 250                                               NaN   1.000000        2
# 251                                               NaN   0.500000        9
# 252                   reimbursements for bee supplies   0.500000       13
# 253                               postdoc coffee hour   1.000000        7
# 254                   reimbursements for bee supplies   0.850000       13
#
#                clusterGroup
# 0                 get ready
# 1                   commute
# 2                  exercise
# 3               maintenance
# 4                  escience
# 5               maintenance
# 6    brainstorm, transition
# 7              kalmia paper
# 8                     snack
# 9              kalmia paper
# 10              maintenance
# 11                    lunch
# 12                  seminar
# 13                    email
# 14             kalmia paper
# 15                 escience
# 17                get ready
# 18                  commute
# 19                 exercise
# 20                   coffee
# 21                     prep
# 22                  meeting
# 23                    email
# 24             kalmia paper
# 25                     prep
# 26             kalmia paper
# 27                 escience
# 28                   coffee
# 29             kalmia paper
# 30                 escience
# ..                      ...
# 222                 seminar
# 223                 seminar
# 224     prep bee experiment
# 225             lab meeting
# 227                 wake up
# 228                 commute
# 229                exercise
# 230     prep bee experiment
# 231            kalmia paper
# 232                   lunch
# 233            kalmia paper
# 235                 wake up
# 236                 commute
# 237                exercise
# 238     prep bee experiment
# 239                 meeting
# 240                 reading
# 241                 seminar
# 242                 reading
# 243           pythonprogram
# 244                 seminar
# 245           pythonprogram
# 247                 wake up
# 248           pythonprogram
# 249                escience
# 250           pythonprogram
# 251                   lunch
# 252               paperwork
# 253                  coffee
# 254               paperwork
#
# [234 rows x 8 columns]

# %%
g = timeCalcs.groupby('clusterGroup')['timeSpent'].sum().reset_index(name='sum')

# %%
g2 = pd.DataFrame(g).sort_values("sum", ascending=False)
g2.index = range(len(g2))
g2.head()
# Out:
#    clusterGroup        sum
# 0  kalmia paper  44.333333
# 1  james' paper  25.316667
# 2       seminar  16.833333
# 3      escience  14.933333
# 4       wake up  14.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(50, 20))
plt.tick_params(axis='both', which='major', labelsize=50)
plt.xlabel('Activity', fontsize = 60)
plt.ylabel('Hours', fontsize = 60)
sns.barplot(g2.clusterGroup, np.array(g2["sum"]))
plt.xticks(rotation="vertical")
plt.show()

# %%
np.array(g["sum"])
# Out:
# array([  0.5       ,   0.5       ,   2.9       ,   3.5       ,
#          2.5       ,   1.5       ,   8.46666667,   5.75      ,
#          4.48333333,   2.75      ,  14.93333333,  10.8       ,
#          0.33333333,   9.41666667,  25.31666667,  44.33333333,
#          5.1       ,   8.23333333,   5.18333333,   7.86666667,
#          1.91666667,   1.5       ,   1.83333333,   0.75      ,
#          1.35      ,   1.83333333,   8.71666667,  11.41666667,
#          1.16666667,   0.66666667,   4.08333333,   7.        ,
#         16.83333333,   0.2       ,   0.83333333,  14.        ])

# %%
len(np.unique(timeCalcs.day))
# Out:
# 22

# %%
g2["sum"].sum()
# Out:
# 238.4666666666667

# %%
g2
# Out:
#               clusterGroup        sum
# 0             kalmia paper  44.333333
# 1             james' paper  25.316667
# 2                  seminar  16.833333
# 3                 escience  14.933333
# 4                  wake up  14.000000
# 5      prep bee experiment  11.416667
# 6                 exercise  10.800000
# 7                get ready   9.416667
# 8                     prep   8.716667
# 9                   coffee   8.466667
# 10                   lunch   8.233333
# 11                 meeting   7.866667
# 12                 reading   7.000000
# 13                 commute   5.750000
# 14             maintenance   5.183333
# 15             lab meeting   5.100000
# 16                   email   4.483333
# 17           pythonprogram   4.083333
# 18                     car   3.500000
# 19  brainstorm, transition   2.900000
# 20                  errand   2.750000
# 21             career fair   2.500000
# 22          mini-symposium   1.916667
# 23        neuroinformatics   1.833333
# 24                planning   1.833333
# 25                climbing   1.500000
# 26              networking   1.500000
# 27               paperwork   1.350000
# 28               prep talk   1.166667
# 29                  snooze   0.833333
# 30                ordering   0.750000
# 31              purchasing   0.666667
# 32               bee order   0.500000
# 33                    bike   0.500000
# 34             gantt chart   0.333333
# 35                   snack   0.200000

# %%
nonWorkActivities = ["bike", "snooze", "exercise", "commute", "climbing", "comute", "wake up", "get ready"]

rowRemove = [g2.clusterGroup[ii] not in nonWorkActivities for ii in range(len(g2))]

# %%
g3 = g2[rowRemove]

# %%
g3["sum"].sum()/len(np.unique(timeCalcs.day))
# Out:
# 8.893939393939393

# %%
len(timeCalcs)
# Out:
# 234

# %%
# calculate hours for each day
rowRemove = [timeCalcs.clusterGroup[ii] not in nonWorkActivities for ii in timeCalcs.index]

timecalcs2 =  timeCalcs[rowRemove]

dailyHours= timecalcs2.groupby("day")['timeSpent'].sum().reset_index(name='sum')
dailyHours.sort_values("sum")
# Out:
#             day        sum
# 0    1 Nov 2017   6.850000
# 13  25 Oct 2017   8.166667
# 4   13 Oct 2017   8.250000
# 3   12 Oct 2017   8.250000
# 10  20 Oct 2017   8.350000
# 20   6 Oct 2017   8.500000
# 7   18 Oct 2017   8.666667
# 14  26 Oct 2017   8.666667
# 19   5 Oct 2017   8.750000
# 9    2 Oct 2017   8.750000
# 18   4 Oct 2017   8.933333
# 11  23 Oct 2017   9.000000
# 1   10 Oct 2017   9.083333
# 6   17 Oct 2017   9.166667
# 21   9 Oct 2017   9.166667
# 12  24 Oct 2017   9.200000
# 15   3 Oct 2017   9.250000
# 17  31 Oct 2017   9.500000
# 8   19 Oct 2017   9.500000
# 2   11 Oct 2017   9.833333
# 5   16 Oct 2017   9.833333
# 16  30 Oct 2017  10.000000

# %%
plt.figure(figsize=(50, 20))
plt.tick_params(axis='both', which='major', labelsize=50)
plt.xlabel('Activity', fontsize = 60)
plt.ylabel('Hours', fontsize = 60)
sns.barplot(g3.clusterGroup, np.array(g3["sum"]))
plt.xticks(rotation="vertical")
plt.show()

# %%
g3
# Out:
#               clusterGroup        sum
# 0             kalmia paper  44.333333
# 1             james' paper  25.316667
# 2                  seminar  16.833333
# 3                 escience  14.933333
# 5      prep bee experiment  11.416667
# 8                     prep   8.716667
# 9                   coffee   8.466667
# 10                   lunch   8.233333
# 11                 meeting   7.866667
# 12                 reading   7.000000
# 14             maintenance   5.183333
# 15             lab meeting   5.100000
# 16                   email   4.483333
# 17           pythonprogram   4.083333
# 18                     car   3.500000
# 19  brainstorm, transition   2.900000
# 20                  errand   2.750000
# 21             career fair   2.500000
# 22          mini-symposium   1.916667
# 23        neuroinformatics   1.833333
# 24                planning   1.833333
# 26              networking   1.500000
# 27               paperwork   1.350000
# 28               prep talk   1.166667
# 30                ordering   0.750000
# 31              purchasing   0.666667
# 32               bee order   0.500000
# 34             gantt chart   0.333333
# 35                   snack   0.200000
