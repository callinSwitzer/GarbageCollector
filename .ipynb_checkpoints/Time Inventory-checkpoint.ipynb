# %%
## analyze time usage google sheet

# %%
import sys
print(sys.version)
print(sys.executable)
# %matplotlib inline
# Out:
# 3.5.4 |Anaconda, Inc.| (default, Oct  5 2017, 02:58:14)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# /Users/cswitzer/anaconda/envs/p35/bin/python

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('https://docs.google.com/spreadsheets/d/' + 
                   '1OPPbkBkkBJf5_TRd_TWioTfNZtfDlUlQiDoCfRpzdoI' +
                   '/export?gid=0&format=csv'
                  )
test.head(5)  #
# Out:
#           day   hour     category productive                           notes
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1         NaN  07:15      commute          n                             NaN
# 2         NaN  07:30     exercise          n                             NaN
# 3         NaN  08:15  maintenance          n  Trying to get title for my car
# 4         NaN  09:26     eScience          y             prep lightning talk

# %%
# %qtconsole

# %%
def cellFillBelow(dataframe, column):
    #loop through cells
    tmp = dataframe[column].copy()
    
    currInfo = tmp[0]
    for ii in range(len(tmp)):
        if pd.isnull(tmp[ii]):
            tmp[ii] = currInfo
        else:
            currInfo = tmp[ii]
    
    return(tmp)

# %%
test['day'] = cellFillBelow(test, 'day')

# %%
test.head()
# Out:
#           day   hour     category productive                           notes
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1  2 Oct 2017  07:15      commute          n                             NaN
# 2  2 Oct 2017  07:30     exercise          n                             NaN
# 3  2 Oct 2017  08:15  maintenance          n  Trying to get title for my car
# 4  2 Oct 2017  09:26     eScience          y             prep lightning talk

# %%
test.tail()
# Out:
#              day   hour                                category productive  \
# 442  13 Dec 2017  14:30                                 seminar        NaN
# 443  13 Dec 2017  16:00  Sonication manuscript -- Data analysis        NaN
# 444  13 Dec 2017  17:00                                     end        NaN
# 445  14 Dec 2017  08:15                                  coffee        NaN
# 446  14 Dec 2017  08:20  Sonication manuscript -- Data analysis        NaN
#
#     notes
# 442   NaN
# 443   NaN
# 444   NaN
# 445   NaN
# 446   NaN

# %%
from datetime import datetime

# %%
times2 = [datetime.strptime(ii, "%H:%M") for ii in test['hour']]



datetime.strftime(times2[0],"%H:%M" )
# Out:
# '06:00'

# %%
timeDiffs = np.diff(times2)

# %%
def decimalHours(timedelta):
    duration =timedelta
    seconds = duration.total_seconds()
    hours = seconds / 3600
    return(hours)

timeDiffsHours = [decimalHours(jj) for jj in timeDiffs]
timeDiffsHours.append(0) # add a zero at the end of the dataset
test["timeSpent"] = timeDiffsHours
test.head()
# Out:
#           day   hour     category productive                           notes  \
# 0  2 Oct 2017  06:00    get ready          n                             NaN
# 1  2 Oct 2017  07:15      commute          n                             NaN
# 2  2 Oct 2017  07:30     exercise          n                             NaN
# 3  2 Oct 2017  08:15  maintenance          n  Trying to get title for my car
# 4  2 Oct 2017  09:26     eScience          y             prep lightning talk
#
#    timeSpent
# 0   1.250000
# 1   0.250000
# 2   0.750000
# 3   1.183333
# 4   0.183333

# %%
# remove last entry for each day
def removeLastOfDay(dataframe, daycolumn):
    #loop through cells
    tmp = dataframe[daycolumn].copy()
    
    dropRows = []
    for ii in range(len(tmp)):
        try:
            if tmp[ii] != tmp[ii + 1]:
                dropRows.append(ii)
        except:
             dropRows.append(ii)
    
    return(dropRows)

# %%
# 439  13 Dec 2017  08:30  Sonication manuscript -- Data analysis        NaN
# 440  13 Dec 2017  11:50                                 seminar        NaN
# 441  13 Dec 2017  12:10  Sonication manuscript -- Data analysis        NaN
# 442  13 Dec 2017  14:30                                 seminar        NaN
# 443  13 Dec 2017  16:00  Sonication manuscript -- Data analysis        NaN
# 445  14 Dec 2017  08:15                                  coffee        NaN
#
#                                             notes  timeSpent
# 0                                             NaN   1.250000
# 1                                             NaN   0.250000
# 2                                             NaN   0.750000
# 3                  Trying to get title for my car   1.183333
# 4                             prep lightning talk   0.183333
# 5    trying to get health insurance cards from UW   0.266667
# 6                                             NaN   0.066667
# 7                            respond to reviewers   0.766667
# 8                                             NaN   0.200000
# 9                                             NaN   0.200000
# 10                           getting MA car title   0.500000
# 11                                            NaN   0.216667
# 12                                            NaN   1.250000
# 13        prepping for eScience teaching tomorrow   0.600000
# 14                                            NaN   1.066667
# 15                                  Welcome event   2.250000
# 17                                            NaN   1.250000
# 18                                            NaN   0.250000
# 19                                            NaN   0.750000
# 20                                            NaN   0.566667
# 21                      prep for meeting with Tom   0.183333
# 22                                       with tom   1.000000
# 23                                            NaN   0.266667
# 24                                            NaN   0.050000
# 25                      prep for meeting with Tom   0.066667
# 26                                            NaN   1.366667
# 27                                 Lunch seminar    1.500000
# 28                                            NaN   0.250000
# 29                                            NaN   3.250000
# 30                                        seminar   0.750000
# ..                                            ...        ...
# 408                                           NaN   0.750000
# 409                                           NaN   2.500000
# 410                                           NaN   5.000000
# 411                                           NaN   1.500000
# 413                                           NaN   1.500000
# 414                                           NaN   4.250000
# 415                                           NaN   2.500000
# 416                                           NaN   1.500000
# 418                                           NaN   3.000000
# 419                                           NaN   0.500000
# 420                                           NaN   6.000000
# 421                                           NaN   2.000000
# 422                                           NaN   2.500000
# 424                                           NaN  11.000000
# 426                                           NaN   5.000000
# 428                                           NaN   1.000000
# 429                                           NaN   4.000000
# 430                                           NaN   1.500000
# 432                                           NaN   0.500000
# 433                                           NaN   1.750000
# 434                                           NaN   1.750000
# 435                                           NaN   3.500000
# 437                                           NaN   0.750000
# 438                                           NaN   0.250000
# 439                                           NaN   3.333333
# 440                                           NaN   0.333333
# 441                                           NaN   2.333333
# 442                                           NaN   1.500000
# 443                                           NaN   1.000000
# 445                                           NaN   0.083333
#
# [395 rows x 6 columns]

# %%
# subset since specified day

def cellremoveAbove(dataframe, column, dayCut):
    #loop through cells
    
    tmp = dataframe[column].copy()

    for ii in range(len(tmp)):
        if tmp.iloc[ii] == dayCut:
            break
    return(ii)

# %%
cc = cellremoveAbove(timeCalcs, "day", "30 Nov 2017")

# %%
timeCalcs = timeCalcs.iloc[cc:, ].copy()

# %%
g = timeCalcs.groupby('category')['timeSpent'].sum().reset_index(name='sum')

# %%
g2 = pd.DataFrame(g).sort_values("sum", ascending=False)
g2.index = range(len(g2))
g2.head()
# Out:
#                                  category        sum
# 0       SICB Talk / Sonication Manuscript  34.083333
# 1                                   break  17.250000
# 2                             lab retreat  16.000000
# 3  Sonication manuscript -- Data analysis  11.916667
# 4                                 seminar  10.666667

# %%
plt.figure(figsize=(50, 20))
plt.tick_params(axis='both', which='major', labelsize=50)
plt.xlabel('Activity', fontsize = 60)
plt.ylabel('Hours', fontsize = 60)
sns.barplot(g2["category"], g2["sum"])
plt.xticks(rotation="vertical")
plt.show()

# %%
g2
# Out:
#                                   category        sum
# 0        SICB Talk / Sonication Manuscript  34.083333
# 1                                    break  17.250000
# 2                              lab retreat  16.000000
# 3   Sonication manuscript -- Data analysis  11.916667
# 4                                  seminar  10.666667
# 5                  neural network learning   5.750000
# 6                                   coffee   3.416667
# 7                                    lunch   3.000000
# 8                                 exercise   2.833333
# 9                                  meeting   2.500000
# 10                          eScience party   1.500000
# 11                                bee care   1.500000
# 12                             lab meeting   1.500000
# 13                        prep for meeting   1.250000
# 14                       promoting my work   1.000000
# 15                                   email   0.500000
# 16                               paperwork   0.500000

# %%
nonWorkActivities = ["bike", "snooze", "exercise", "commute", "climbing", "wake up", "get ready", "coffee", "break", "lunch", "get up"]

rowRemove = [g2.category[ii] not in nonWorkActivities for ii in range(len(g2))]

# %%
g3 = g2[rowRemove]

# %%
g3["sum"].sum()/len(np.unique(timeCalcs.day))
# Out:
# 6.820512820512821

# %%
len(timeCalcs)
# Out:
# 67

# %%
# calculate hours for each day
rowRemove = [timeCalcs.category[ii] not in nonWorkActivities for ii in timeCalcs.index]

timecalcs2 =  timeCalcs[rowRemove]

dailyHours= timecalcs2.groupby("day")['timeSpent'].sum().reset_index(name='sum')
dailyHours.sort_values("sum")
# Out:
#             day        sum
# 2   11 Dec 2017   2.500000
# 1   10 Dec 2017   5.000000
# 6    4 Dec 2017   6.500000
# 7    5 Dec 2017   6.666667
# 3   12 Dec 2017   7.000000
# 9    7 Dec 2017   7.250000
# 0    1 Dec 2017   7.500000
# 5   30 Nov 2017   7.500000
# 8    6 Dec 2017   7.750000
# 4   13 Dec 2017   8.500000
# 11   9 Dec 2017  11.000000
# 10   8 Dec 2017  11.500000

# %%
plt.figure(figsize=(50, 20))
plt.tick_params(axis='both', which='major', labelsize=50)
plt.xlabel('Activity', fontsize = 60)
plt.ylabel('Hours', fontsize = 60)
sns.barplot(g3["category"], g3["sum"])
plt.xticks(rotation="vertical")
plt.show()

# %%
g4 = g3.loc[g3["sum"] > 1.0,:]

# %%
g4
# Out:
#                                   category        sum
# 0        SICB Talk / Sonication Manuscript  34.083333
# 2                              lab retreat  16.000000
# 3   Sonication manuscript -- Data analysis  11.916667
# 4                                  seminar  10.666667
# 5                  neural network learning   5.750000
# 9                                  meeting   2.500000
# 10                          eScience party   1.500000
# 11                                bee care   1.500000
# 12                             lab meeting   1.500000
# 13                        prep for meeting   1.250000

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(25, 15))
plt.tick_params(axis='both', which='major', labelsize=50)
plt.xlabel('Activity', fontsize = 60)
plt.ylabel('Hours', fontsize = 60)
sns.barplot(g4["sum"], g4["category"])
plt.xticks(rotation="horizontal")
plt.ylabel("Activity")
plt.xlabel("Hours")
plt.tight_layout()
plt.title("Top activities since 30 Nov", fontsize=50)
plt.savefig("/Users/cswitzer/Dropbox/CallinStuff/weeklyMeetings/TimeSince31Oct.pdf", bbox_inches = 'tight')
sns.despine(left=True, bottom=True)
plt.show()

# %%
np.sum(g4["sum"])
# Out:
# 160.95000000000002
